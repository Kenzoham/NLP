# %%
#Referensi: https://www.linkedin.com/pulse/how-scrape-google-play-reviews-4-simple-steps-using-python-kundi/
#download library google-play-scraper
# !pip install google-play-scraper
# Out:
# Requirement already satisfied: google-play-scraper in c:\users\abdullahilham\appdata\local\programs\python\python311\lib\site-packages (1.2.7)

# %%
from google_play_scraper import app

import pandas as pd

import numpy as np

# %%
#scrape jumlah ulasan yang diinginkan
from google_play_scraper import Sort, reviews

result, continuation_token = reviews(
    'id.co.sevima.edlink',
    lang='id',  #disini kita mau men scrape data ulasan aplikasi shopee yang berada di google play store
    country='id', #kita setting bahasa nya menjadi bahasa indonesia
    sort=Sort.MOST_RELEVANT, # # kemudian kita gunakan most_relevan untuk mendapatkan ulasan yang paling relevant
    count=1000, # disini jumlah ulasan yang mau kita ambil ada seribu
    filter_score_with=None # # kemudian di filter_score kita gunakan None untuk mengambil semua score atau ratting bintang 1 sampai 5
)

# %%
df_busu = pd.DataFrame(np.array(result),columns=['review'])

df_busu = df_busu.join(pd.DataFrame(df_busu.pop('review').tolist()))

df_busu.head()
# Out:
#                                reviewId  \
# 0  13cc6b4e-d596-4c3c-8f06-a4793e3027ff
# 1  bf2adc4d-642e-4e2a-93a1-c368dc2b525d
# 2  bb3f30c8-2bbc-4c0e-8ef5-4c9bf31bbc9d
# 3  be6cccbb-9f2e-4f65-bb4e-fa1dd4da8d1d
# 4  c26f77cd-05f8-42f0-9a4f-5de8a2a68073
#
#                                  userName  \
# 0                              Lucy Steel
# 1                      11IPS2.15 Katarina
# 2                             Arina putri
# 3                        Topik Nurmansyah
# 4  Amanda nurfadilla Rizki wahyuning dari
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/ALV-U...
# 1  https://play-lh.googleusercontent.com/a-/ALV-U...
# 2  https://play-lh.googleusercontent.com/a-/ALV-U...
# 3  https://play-lh.googleusercontent.com/a-/ALV-U...
# 4  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                              content  score  thumbsUpCount  \
# 0  Server selalu sibuk, saat mengerjakan kuis, sa...      1             14
# 1  Aplikasi ini sangat bagus untuk perkuliahan, t...      4              0
# 2  Ko saya ganti HP jadi G ada notif tugas atau k...      2              0
# 3  Scan absennya gak bisa di zoom, jadi kepaksa h...      1              2
# 4  Halo kak ini kenapa ya edlink saya ga muncul t...      3              0
#
#   reviewCreatedVersion                  at  \
# 0                4.8.4 2024-09-30 14:11:30
# 1                4.8.5 2024-11-19 12:58:38
# 2                4.8.5 2025-01-07 20:57:01
# 3                4.8.4 2024-10-09 15:52:42
# 4                4.8.5 2024-12-29 20:22:09
#
#                                         replyContent           repliedAt  \
# 0  Hai Kak Lucy, mohon maaf untuk kendalanya. Jik... 2024-09-30 15:30:09
# 1  Halo Kak, terima kasih atas masukannya. Coba k... 2024-11-19 14:29:18
# 2  Hai Kak, apakah bisa dikirimkan untuk NIM dan ... 2025-01-08 10:38:24
# 3  Hi Kak, mohon maaf atas ketidaknyamanannya. Se... 2024-10-03 11:15:05
# 4  Halo Kak, bisa kirimkan NIM, asal PT dan nama ... 2024-12-29 20:24:06
#
#   appVersion
# 0      4.8.4
# 1      4.8.5
# 2      4.8.5
# 3      4.8.4
# 4      4.8.5

# %%
len(df_busu.index) #kemudian hitung kembali berapa jumlah data yg didapatkan
# Out:
# 1000

# %%
df_busu[['userName', 'score','at', 'content']].head()  #dari scrapping tsb didapatkan banyak sekali kolom, kemudian kolom" tsb kita filter
                                                        #sehingga didapatkan kolom username, score, at dan content
# Out:
#                                  userName  score                  at  \
# 0                              Lucy Steel      1 2024-09-30 14:11:30
# 1                      11IPS2.15 Katarina      4 2024-11-19 12:58:38
# 2                             Arina putri      2 2025-01-07 20:57:01
# 3                        Topik Nurmansyah      1 2024-10-09 15:52:42
# 4  Amanda nurfadilla Rizki wahyuning dari      3 2024-12-29 20:22:09
#
#                                              content
# 0  Server selalu sibuk, saat mengerjakan kuis, sa...
# 1  Aplikasi ini sangat bagus untuk perkuliahan, t...
# 2  Ko saya ganti HP jadi G ada notif tugas atau k...
# 3  Scan absennya gak bisa di zoom, jadi kepaksa h...
# 4  Halo kak ini kenapa ya edlink saya ga muncul t...

# %%
#Run This Code to Sort the Data By Date 

new_df = df_busu[['userName', 'score','at', 'content']]
sorted_df = new_df.sort_values(by='at', ascending=False) #Sort by Newst, change to True if you want to sort by Oldest.
sorted_df.head()
# Out:
#              userName  score                  at  \
# 305            Samuel      4 2025-01-15 01:13:19
# 329            BoKita      1 2025-01-14 11:57:21
# 330  Muhammad Yusriel      3 2025-01-14 10:27:27
# 749    Cristoper Raya      3 2025-01-09 23:48:15
# 18    Aji Prasetiyo Æ      1 2025-01-08 11:42:10
#
#                                                content
# 305  Bintang 5 jika sevima menyediakan mode gelap d...
# 329                        Tidak bisa masuk mulu berak
# 330  Mohon untuk update bagian upload file, tambahk...
# 749  perbanyak improvisasi,ini app masih banyak kur...
# 18   Izin melapor ketua aplikasi ngebug jaringan pa...

# %%
my_df = sorted_df[['userName', 'score','at', 'content']] #kemudian kita simpan ke variabel my_df

# %%
my_df=my_df[['content', 'score']]#karena kita hanya membutuhkan kolom content dan score maka kita lakukan filter kolom lgi hingga menyisakan kolom content dan score.

# %%
my_df.head()
# Out:
#                                                content  score
# 305  Bintang 5 jika sevima menyediakan mode gelap d...      4
# 329                        Tidak bisa masuk mulu berak      1
# 330  Mohon untuk update bagian upload file, tambahk...      3
# 749  perbanyak improvisasi,ini app masih banyak kur...      3
# 18   Izin melapor ketua aplikasi ngebug jaringan pa...      1

# %%
def pelabelan(score):
  if score < 3:
    return 'Negatif'
  elif score == 4 :
    return 'Positif'
  elif score == 5 :
    return 'Positif'
my_df['Label'] = my_df ['score'].apply(pelabelan)
my_df.head(50)
# Out:
#                                                content  score    Label
# 305  Bintang 5 jika sevima menyediakan mode gelap d...      4  Positif
# 329                        Tidak bisa masuk mulu berak      1  Negatif
# 330  Mohon untuk update bagian upload file, tambahk...      3     None
# 749  perbanyak improvisasi,ini app masih banyak kur...      3     None
# 18   Izin melapor ketua aplikasi ngebug jaringan pa...      1  Negatif
# 2    Ko saya ganti HP jadi G ada notif tugas atau k...      2  Negatif
# 331  Pada akun edlink saya gak ada fitur keuangan j...      3     None
# 105  membantu banget buat liat nilai nilai semester...      5  Positif
# 5    Aplikasi tidak bagus, saya jadi tidak bisa upl...      1  Negatif
# 4    Halo kak ini kenapa ya edlink saya ga muncul t...      3     None
# 16   Ada bug kah ?? Kok ga bisa login google ataupu...      3     None
# 516  Pengumpulan UAS maupun tugas saya tidak bisa d...      4  Positif
# 149  Punten kie mah, masa iya ngimpulaken tugas tel...      1  Negatif
# 354  ka tolong di bantu, saya tidak bisa mendaftark...      2  Negatif
# 17   Durasi waktu pengerjaan tugas dan jam tidak se...      1  Negatif
# 283                 bagus, terkadang ada bug absen aja      4  Positif
# 68   banyak terjadi kesalahan pada server, tolong d...      1  Negatif
# 316                    Kok gak bisa nge unduh file sih      1  Negatif
# 753                                  Bagusss dan mudah      5  Positif
# 15   Mohon maaf kenapa ya setiap saya buka apk edli...      2  Negatif
# 155  Buka materi perkuliahan dan download materi fi...      1  Negatif
# 6    makasih sudah di perbaiki dari saat setelah wa...      5  Positif
# 1    Aplikasi ini sangat bagus untuk perkuliahan, t...      4  Positif
# 19   saya make edlink bagus sih namun sering kali k...      4  Positif
# 747  Sangat2 membantu sekali ... Semoga semakin baik 😊      5  Positif
# 752           Baru mau coba,hehehe.Sebenernya terpaksa      4  Positif
# 289  Sangat membantu dan memudahkan dalam proses be...      5  Positif
# 353  tiap kali buka selalu terjadi kesalahan pada s...      1  Negatif
# 7    Teruntuk developer Apakah aplikasi nay sedang ...      1  Negatif
# 510           Fitur chat antar mahasiswa sangat lambat      5  Positif
# 754                            gakk bisa ubah photo!!!      1  Negatif
# 8    Bagus di saya sih. Cuman waktu ngumpul ujian d...      5  Positif
# 318                      Kameranya tidak bisa di zoom😡      3     None
# 65   edlink makin sini makin jelek, apalagi kalo di...      2  Negatif
# 154  Mohon tambahkan menu cek jadwal UTS dan UAS ka...      3     None
# 66   Update baru ga bisa absen scan wak, yang bener...      1  Negatif
# 339  Min tolong di perbaiki lagi di bagian quiz nya...      1  Negatif
# 809  Saat mengerjakan quiz ngebug dan jawaban benar...      1  Negatif
# 863                                    Sangat membantu      5  Positif
# 69   Kenapa setelah hapus foto profil terus mau gan...      5  Positif
# 25   Terlalu sering kesalahan server tolong fix, sa...      1  Negatif
# 89   sekarang presensi QR susah sekali karena pakai...      2  Negatif
# 745  Presensi scan wajahnya di perbaikilah bikin or...      1  Negatif
# 480  Min kok matkul saya bahasa inggris ilang di ru...      3     None
# 864   Sinyal lancar tapi tetep muter terus apk GK guna      1  Negatif
# 313  Kak kenapa sekarang edlink aku tulisannya terj...      3     None
# 746                          Sangat membantu pelajaran      5  Positif
# 3    Scan absennya gak bisa di zoom, jadi kepaksa h...      1  Negatif
# 9    Halo, kak. Waktu sedang mengerjakan quiz kamer...      4  Positif
# 26   Pada saat mengupload tugas tidak ada notifikas...      1  Negatif

# %%
my_df.to_csv("scrapped_edlink.csv", index = False)  #kemudian save menjadi file csv

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
my_df = pd.read_csv('scrapped_edlink.csv')
my_df.head(50)
# Out:
#                                               content  score    Label
# 0   Bintang 5 jika sevima menyediakan mode gelap d...      4  Positif
# 1                         Tidak bisa masuk mulu berak      1  Negatif
# 2   Mohon untuk update bagian upload file, tambahk...      3      NaN
# 3   perbanyak improvisasi,ini app masih banyak kur...      3      NaN
# 4   Izin melapor ketua aplikasi ngebug jaringan pa...      1  Negatif
# 5   Ko saya ganti HP jadi G ada notif tugas atau k...      2  Negatif
# 6   Pada akun edlink saya gak ada fitur keuangan j...      3      NaN
# 7   membantu banget buat liat nilai nilai semester...      5  Positif
# 8   Aplikasi tidak bagus, saya jadi tidak bisa upl...      1  Negatif
# 9   Halo kak ini kenapa ya edlink saya ga muncul t...      3      NaN
# 10  Ada bug kah ?? Kok ga bisa login google ataupu...      3      NaN
# 11  Pengumpulan UAS maupun tugas saya tidak bisa d...      4  Positif
# 12  Punten kie mah, masa iya ngimpulaken tugas tel...      1  Negatif
# 13  ka tolong di bantu, saya tidak bisa mendaftark...      2  Negatif
# 14  Durasi waktu pengerjaan tugas dan jam tidak se...      1  Negatif
# 15                 bagus, terkadang ada bug absen aja      4  Positif
# 16  banyak terjadi kesalahan pada server, tolong d...      1  Negatif
# 17                    Kok gak bisa nge unduh file sih      1  Negatif
# 18                                  Bagusss dan mudah      5  Positif
# 19  Mohon maaf kenapa ya setiap saya buka apk edli...      2  Negatif
# 20  Buka materi perkuliahan dan download materi fi...      1  Negatif
# 21  makasih sudah di perbaiki dari saat setelah wa...      5  Positif
# 22  Aplikasi ini sangat bagus untuk perkuliahan, t...      4  Positif
# 23  saya make edlink bagus sih namun sering kali k...      4  Positif
# 24  Sangat2 membantu sekali ... Semoga semakin baik 😊      5  Positif
# 25           Baru mau coba,hehehe.Sebenernya terpaksa      4  Positif
# 26  Sangat membantu dan memudahkan dalam proses be...      5  Positif
# 27  tiap kali buka selalu terjadi kesalahan pada s...      1  Negatif
# 28  Teruntuk developer Apakah aplikasi nay sedang ...      1  Negatif
# 29           Fitur chat antar mahasiswa sangat lambat      5  Positif
# 30                            gakk bisa ubah photo!!!      1  Negatif
# 31  Bagus di saya sih. Cuman waktu ngumpul ujian d...      5  Positif
# 32                      Kameranya tidak bisa di zoom😡      3      NaN
# 33  edlink makin sini makin jelek, apalagi kalo di...      2  Negatif
# 34  Mohon tambahkan menu cek jadwal UTS dan UAS ka...      3      NaN
# 35  Update baru ga bisa absen scan wak, yang bener...      1  Negatif
# 36  Min tolong di perbaiki lagi di bagian quiz nya...      1  Negatif
# 37  Saat mengerjakan quiz ngebug dan jawaban benar...      1  Negatif
# 38                                    Sangat membantu      5  Positif
# 39  Kenapa setelah hapus foto profil terus mau gan...      5  Positif
# 40  Terlalu sering kesalahan server tolong fix, sa...      1  Negatif
# 41  sekarang presensi QR susah sekali karena pakai...      2  Negatif
# 42  Presensi scan wajahnya di perbaikilah bikin or...      1  Negatif
# 43  Min kok matkul saya bahasa inggris ilang di ru...      3      NaN
# 44   Sinyal lancar tapi tetep muter terus apk GK guna      1  Negatif
# 45  Kak kenapa sekarang edlink aku tulisannya terj...      3      NaN
# 46                          Sangat membantu pelajaran      5  Positif
# 47  Scan absennya gak bisa di zoom, jadi kepaksa h...      1  Negatif
# 48  Halo, kak. Waktu sedang mengerjakan quiz kamer...      4  Positif
# 49  Pada saat mengupload tugas tidak ada notifikas...      1  Negatif

# %%
# info() digunakan untuk menampilkan informasi detail tentang dataframe, 
#seperti jumlah baris data, nama-nama kolom berserta jumlah data dan tipe datanya, dan sebagainya.
my_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   content  1000 non-null   object
#  1   score    1000 non-null   int64
#  2   Label    881 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 23.6+ KB

# %%
#Tampilkan setiap baris yang memiliki nilai null (NaN) pada kolom apapun
#Gunakan fitur isna() yang disediakan library pandas
my_df.isna()
# Out:
#      content  score  Label
# 0      False  False  False
# 1      False  False  False
# 2      False  False   True
# 3      False  False   True
# 4      False  False  False
# ..       ...    ...    ...
# 995    False  False  False
# 996    False  False  False
# 997    False  False   True
# 998    False  False  False
# 999    False  False  False
#
# [1000 rows x 3 columns]

# %%
my_df.isna().any()
# Out:
# content    False
# score      False
# Label       True
# dtype: bool

# %%
my_df.describe()
# Out:
#              score
# count  1000.000000
# mean      2.633000
# std       1.641037
# min       1.000000
# 25%       1.000000
# 50%       2.000000
# 75%       4.000000
# max       5.000000

# %%
#mencari jumlah baris data yang bernilai null
#terdapat kolom label memiliki nilai kosong
my_df.isnull().sum()
# Out:
# content      0
# score        0
# Label      119
# dtype: int64

# %%
my_df.dropna(subset=['Label'],inplace = True)

# %%
my_df.isnull().sum()
# Out:
# content    0
# score      0
# Label      0
# dtype: int64

# %%
my_df.head(50)
# Out:
#                                               content  score    Label
# 0   Bintang 5 jika sevima menyediakan mode gelap d...      4  Positif
# 1                         Tidak bisa masuk mulu berak      1  Negatif
# 4   Izin melapor ketua aplikasi ngebug jaringan pa...      1  Negatif
# 5   Ko saya ganti HP jadi G ada notif tugas atau k...      2  Negatif
# 7   membantu banget buat liat nilai nilai semester...      5  Positif
# 8   Aplikasi tidak bagus, saya jadi tidak bisa upl...      1  Negatif
# 11  Pengumpulan UAS maupun tugas saya tidak bisa d...      4  Positif
# 12  Punten kie mah, masa iya ngimpulaken tugas tel...      1  Negatif
# 13  ka tolong di bantu, saya tidak bisa mendaftark...      2  Negatif
# 14  Durasi waktu pengerjaan tugas dan jam tidak se...      1  Negatif
# 15                 bagus, terkadang ada bug absen aja      4  Positif
# 16  banyak terjadi kesalahan pada server, tolong d...      1  Negatif
# 17                    Kok gak bisa nge unduh file sih      1  Negatif
# 18                                  Bagusss dan mudah      5  Positif
# 19  Mohon maaf kenapa ya setiap saya buka apk edli...      2  Negatif
# 20  Buka materi perkuliahan dan download materi fi...      1  Negatif
# 21  makasih sudah di perbaiki dari saat setelah wa...      5  Positif
# 22  Aplikasi ini sangat bagus untuk perkuliahan, t...      4  Positif
# 23  saya make edlink bagus sih namun sering kali k...      4  Positif
# 24  Sangat2 membantu sekali ... Semoga semakin baik 😊      5  Positif
# 25           Baru mau coba,hehehe.Sebenernya terpaksa      4  Positif
# 26  Sangat membantu dan memudahkan dalam proses be...      5  Positif
# 27  tiap kali buka selalu terjadi kesalahan pada s...      1  Negatif
# 28  Teruntuk developer Apakah aplikasi nay sedang ...      1  Negatif
# 29           Fitur chat antar mahasiswa sangat lambat      5  Positif
# 30                            gakk bisa ubah photo!!!      1  Negatif
# 31  Bagus di saya sih. Cuman waktu ngumpul ujian d...      5  Positif
# 33  edlink makin sini makin jelek, apalagi kalo di...      2  Negatif
# 35  Update baru ga bisa absen scan wak, yang bener...      1  Negatif
# 36  Min tolong di perbaiki lagi di bagian quiz nya...      1  Negatif
# 37  Saat mengerjakan quiz ngebug dan jawaban benar...      1  Negatif
# 38                                    Sangat membantu      5  Positif
# 39  Kenapa setelah hapus foto profil terus mau gan...      5  Positif
# 40  Terlalu sering kesalahan server tolong fix, sa...      1  Negatif
# 41  sekarang presensi QR susah sekali karena pakai...      2  Negatif
# 42  Presensi scan wajahnya di perbaikilah bikin or...      1  Negatif
# 44   Sinyal lancar tapi tetep muter terus apk GK guna      1  Negatif
# 46                          Sangat membantu pelajaran      5  Positif
# 47  Scan absennya gak bisa di zoom, jadi kepaksa h...      1  Negatif
# 48  Halo, kak. Waktu sedang mengerjakan quiz kamer...      4  Positif
# 49  Pada saat mengupload tugas tidak ada notifikas...      1  Negatif
# 50  Sistem quiz error, soal ada 24,udah isi sumua,...      1  Negatif
# 51  Bikin auto save lah kak, bjir lah gw bikin jaw...      5  Positif
# 52  BENERIN SERVER NYA OIIII JANGAN UPDATE FITUR M...      1  Negatif
# 54  Sekarang edlink kalo isi quiz mau record atau ...      1  Negatif
# 55  Tolong adakan fitur zoom pada fitur scan code ...      2  Negatif
# 56                                  Ga berfungsi baik      1  Negatif
# 57  Hallo.aplikasi Edlink sudah ada di perangkat l...      5  Positif
# 58                       kode tidak terkirim ke email      1  Negatif
# 59  Server selalu sibuk, saat mengerjakan kuis, sa...      1  Negatif

# %%
my_df.to_csv("sevimaprocessing.csv", index = False)  #simpan hasil file data cleaning dengan nama shopeepreprocessing.csv

# %%
import pandas as pd
df = pd.read_csv('sevimaprocessing.csv')
df.head(50)
# Out:
#                                               content  score    Label
# 0   Bintang 5 jika sevima menyediakan mode gelap d...      4  Positif
# 1                         Tidak bisa masuk mulu berak      1  Negatif
# 2   Izin melapor ketua aplikasi ngebug jaringan pa...      1  Negatif
# 3   Ko saya ganti HP jadi G ada notif tugas atau k...      2  Negatif
# 4   membantu banget buat liat nilai nilai semester...      5  Positif
# 5   Aplikasi tidak bagus, saya jadi tidak bisa upl...      1  Negatif
# 6   Pengumpulan UAS maupun tugas saya tidak bisa d...      4  Positif
# 7   Punten kie mah, masa iya ngimpulaken tugas tel...      1  Negatif
# 8   ka tolong di bantu, saya tidak bisa mendaftark...      2  Negatif
# 9   Durasi waktu pengerjaan tugas dan jam tidak se...      1  Negatif
# 10                 bagus, terkadang ada bug absen aja      4  Positif
# 11  banyak terjadi kesalahan pada server, tolong d...      1  Negatif
# 12                    Kok gak bisa nge unduh file sih      1  Negatif
# 13                                  Bagusss dan mudah      5  Positif
# 14  Mohon maaf kenapa ya setiap saya buka apk edli...      2  Negatif
# 15  Buka materi perkuliahan dan download materi fi...      1  Negatif
# 16  makasih sudah di perbaiki dari saat setelah wa...      5  Positif
# 17  Aplikasi ini sangat bagus untuk perkuliahan, t...      4  Positif
# 18  saya make edlink bagus sih namun sering kali k...      4  Positif
# 19  Sangat2 membantu sekali ... Semoga semakin baik 😊      5  Positif
# 20           Baru mau coba,hehehe.Sebenernya terpaksa      4  Positif
# 21  Sangat membantu dan memudahkan dalam proses be...      5  Positif
# 22  tiap kali buka selalu terjadi kesalahan pada s...      1  Negatif
# 23  Teruntuk developer Apakah aplikasi nay sedang ...      1  Negatif
# 24           Fitur chat antar mahasiswa sangat lambat      5  Positif
# 25                            gakk bisa ubah photo!!!      1  Negatif
# 26  Bagus di saya sih. Cuman waktu ngumpul ujian d...      5  Positif
# 27  edlink makin sini makin jelek, apalagi kalo di...      2  Negatif
# 28  Update baru ga bisa absen scan wak, yang bener...      1  Negatif
# 29  Min tolong di perbaiki lagi di bagian quiz nya...      1  Negatif
# 30  Saat mengerjakan quiz ngebug dan jawaban benar...      1  Negatif
# 31                                    Sangat membantu      5  Positif
# 32  Kenapa setelah hapus foto profil terus mau gan...      5  Positif
# 33  Terlalu sering kesalahan server tolong fix, sa...      1  Negatif
# 34  sekarang presensi QR susah sekali karena pakai...      2  Negatif
# 35  Presensi scan wajahnya di perbaikilah bikin or...      1  Negatif
# 36   Sinyal lancar tapi tetep muter terus apk GK guna      1  Negatif
# 37                          Sangat membantu pelajaran      5  Positif
# 38  Scan absennya gak bisa di zoom, jadi kepaksa h...      1  Negatif
# 39  Halo, kak. Waktu sedang mengerjakan quiz kamer...      4  Positif
# 40  Pada saat mengupload tugas tidak ada notifikas...      1  Negatif
# 41  Sistem quiz error, soal ada 24,udah isi sumua,...      1  Negatif
# 42  Bikin auto save lah kak, bjir lah gw bikin jaw...      5  Positif
# 43  BENERIN SERVER NYA OIIII JANGAN UPDATE FITUR M...      1  Negatif
# 44  Sekarang edlink kalo isi quiz mau record atau ...      1  Negatif
# 45  Tolong adakan fitur zoom pada fitur scan code ...      2  Negatif
# 46                                  Ga berfungsi baik      1  Negatif
# 47  Hallo.aplikasi Edlink sudah ada di perangkat l...      5  Positif
# 48                       kode tidak terkirim ke email      1  Negatif
# 49  Server selalu sibuk, saat mengerjakan kuis, sa...      1  Negatif

# %%
import re
def  clean_text(df, text_field, new_text_field_name):
    my_df[new_text_field_name] = my_df[text_field].str.lower()
    my_df[new_text_field_name] = my_df[new_text_field_name].apply(lambda elem: re.sub(r"(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)|^rt|http.+?", "", elem))  
    # remove numbers
    my_df[new_text_field_name] = my_df[new_text_field_name].apply(lambda elem: re.sub(r"\d+", "", elem)) 
    return my_df

# %%
my_df['text_clean'] = my_df['content'].str.lower()
my_df['text_clean']
data_clean = clean_text(my_df, 'content', 'text_clean')
data_clean.head(10)
# Out:
#                                               content  score    Label  \
# 0   Bintang 5 jika sevima menyediakan mode gelap d...      4  Positif
# 1                         Tidak bisa masuk mulu berak      1  Negatif
# 4   Izin melapor ketua aplikasi ngebug jaringan pa...      1  Negatif
# 5   Ko saya ganti HP jadi G ada notif tugas atau k...      2  Negatif
# 7   membantu banget buat liat nilai nilai semester...      5  Positif
# 8   Aplikasi tidak bagus, saya jadi tidak bisa upl...      1  Negatif
# 11  Pengumpulan UAS maupun tugas saya tidak bisa d...      4  Positif
# 12  Punten kie mah, masa iya ngimpulaken tugas tel...      1  Negatif
# 13  ka tolong di bantu, saya tidak bisa mendaftark...      2  Negatif
# 14  Durasi waktu pengerjaan tugas dan jam tidak se...      1  Negatif
#
#                                            text_clean
# 0   bintang  jika sevima menyediakan mode gelap di...
# 1                         tidak bisa masuk mulu berak
# 4   izin melapor ketua aplikasi ngebug jaringan pa...
# 5   ko saya ganti hp jadi g ada notif tugas atau k...
# 7   membantu banget buat liat nilai nilai semester...
# 8   aplikasi tidak bagus saya jadi tidak bisa uplo...
# 11  pengumpulan uas maupun tugas saya tidak bisa d...
# 12  punten kie mah masa iya ngimpulaken tugas tela...
# 13  ka tolong di bantu saya tidak bisa mendaftarka...
# 14  durasi waktu pengerjaan tugas dan jam tidak se...

# %%
import nltk.corpus
nltk.download('stopwords')
from nltk.corpus import stopwords
stop = stopwords.words('indonesian')
data_clean['text_StopWord'] = data_clean['text_clean'].apply(lambda x:' '.join([word for word in x.split() if word not in (stop)]))
data_clean.head(50)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\abdullahilham\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#                                               content  score    Label  \
# 0   Bintang 5 jika sevima menyediakan mode gelap d...      4  Positif
# 1                         Tidak bisa masuk mulu berak      1  Negatif
# 4   Izin melapor ketua aplikasi ngebug jaringan pa...      1  Negatif
# 5   Ko saya ganti HP jadi G ada notif tugas atau k...      2  Negatif
# 7   membantu banget buat liat nilai nilai semester...      5  Positif
# 8   Aplikasi tidak bagus, saya jadi tidak bisa upl...      1  Negatif
# 11  Pengumpulan UAS maupun tugas saya tidak bisa d...      4  Positif
# 12  Punten kie mah, masa iya ngimpulaken tugas tel...      1  Negatif
# 13  ka tolong di bantu, saya tidak bisa mendaftark...      2  Negatif
# 14  Durasi waktu pengerjaan tugas dan jam tidak se...      1  Negatif
# 15                 bagus, terkadang ada bug absen aja      4  Positif
# 16  banyak terjadi kesalahan pada server, tolong d...      1  Negatif
# 17                    Kok gak bisa nge unduh file sih      1  Negatif
# 18                                  Bagusss dan mudah      5  Positif
# 19  Mohon maaf kenapa ya setiap saya buka apk edli...      2  Negatif
# 20  Buka materi perkuliahan dan download materi fi...      1  Negatif
# 21  makasih sudah di perbaiki dari saat setelah wa...      5  Positif
# 22  Aplikasi ini sangat bagus untuk perkuliahan, t...      4  Positif
# 23  saya make edlink bagus sih namun sering kali k...      4  Positif
# 24  Sangat2 membantu sekali ... Semoga semakin baik 😊      5  Positif
# 25           Baru mau coba,hehehe.Sebenernya terpaksa      4  Positif
# 26  Sangat membantu dan memudahkan dalam proses be...      5  Positif
# 27  tiap kali buka selalu terjadi kesalahan pada s...      1  Negatif
# 28  Teruntuk developer Apakah aplikasi nay sedang ...      1  Negatif
# 29           Fitur chat antar mahasiswa sangat lambat      5  Positif
# 30                            gakk bisa ubah photo!!!      1  Negatif
# 31  Bagus di saya sih. Cuman waktu ngumpul ujian d...      5  Positif
# 33  edlink makin sini makin jelek, apalagi kalo di...      2  Negatif
# 35  Update baru ga bisa absen scan wak, yang bener...      1  Negatif
# 36  Min tolong di perbaiki lagi di bagian quiz nya...      1  Negatif
# 37  Saat mengerjakan quiz ngebug dan jawaban benar...      1  Negatif
# 38                                    Sangat membantu      5  Positif
# 39  Kenapa setelah hapus foto profil terus mau gan...      5  Positif
# 40  Terlalu sering kesalahan server tolong fix, sa...      1  Negatif
# 41  sekarang presensi QR susah sekali karena pakai...      2  Negatif
# 42  Presensi scan wajahnya di perbaikilah bikin or...      1  Negatif
# 44   Sinyal lancar tapi tetep muter terus apk GK guna      1  Negatif
# 46                          Sangat membantu pelajaran      5  Positif
# 47  Scan absennya gak bisa di zoom, jadi kepaksa h...      1  Negatif
# 48  Halo, kak. Waktu sedang mengerjakan quiz kamer...      4  Positif
# 49  Pada saat mengupload tugas tidak ada notifikas...      1  Negatif
# 50  Sistem quiz error, soal ada 24,udah isi sumua,...      1  Negatif
# 51  Bikin auto save lah kak, bjir lah gw bikin jaw...      5  Positif
# 52  BENERIN SERVER NYA OIIII JANGAN UPDATE FITUR M...      1  Negatif
# 54  Sekarang edlink kalo isi quiz mau record atau ...      1  Negatif
# 55  Tolong adakan fitur zoom pada fitur scan code ...      2  Negatif
# 56                                  Ga berfungsi baik      1  Negatif
# 57  Hallo.aplikasi Edlink sudah ada di perangkat l...      5  Positif
# 58                       kode tidak terkirim ke email      1  Negatif
# 59  Server selalu sibuk, saat mengerjakan kuis, sa...      1  Negatif
#
#                                            text_clean  \
# 0   bintang  jika sevima menyediakan mode gelap di...
# 1                         tidak bisa masuk mulu berak
# 4   izin melapor ketua aplikasi ngebug jaringan pa...
# 5   ko saya ganti hp jadi g ada notif tugas atau k...
# 7   membantu banget buat liat nilai nilai semester...
# 8   aplikasi tidak bagus saya jadi tidak bisa uplo...
# 11  pengumpulan uas maupun tugas saya tidak bisa d...
# 12  punten kie mah masa iya ngimpulaken tugas tela...
# 13  ka tolong di bantu saya tidak bisa mendaftarka...
# 14  durasi waktu pengerjaan tugas dan jam tidak se...
# 15                  bagus terkadang ada bug absen aja
# 16  banyak terjadi kesalahan pada server tolong di...
# 17                    kok gak bisa nge unduh file sih
# 18                                  bagusss dan mudah
# 19  mohon maaf kenapa ya setiap saya buka apk edli...
# 20  buka materi perkuliahan dan download materi fi...
# 21  makasih sudah di perbaiki dari saat setelah wa...
# 22  aplikasi ini sangat bagus untuk perkuliahan ta...
# 23  saya make edlink bagus sih namun sering kali k...
# 24       sangat membantu sekali  semoga semakin baik
# 25             baru mau cobahehehesebenernya terpaksa
# 26  sangat membantu dan memudahkan dalam proses be...
# 27  tiap kali buka selalu terjadi kesalahan pada s...
# 28  teruntuk developer apakah aplikasi nay sedang ...
# 29           fitur chat antar mahasiswa sangat lambat
# 30                               gakk bisa ubah photo
# 31  bagus di saya sih cuman waktu ngumpul ujian di...
# 33  edlink makin sini makin jelek apalagi kalo dib...
# 35  update baru ga bisa absen scan wak yang bener aja
# 36  min tolong di perbaiki lagi di bagian quiz nya...
# 37  saat mengerjakan quiz ngebug dan jawaban benar...
# 38                                    sangat membantu
# 39  kenapa setelah hapus foto profil terus mau gan...
# 40  terlalu sering kesalahan server tolong fix say...
# 41  sekarang presensi qr susah sekali karena pakai...
# 42  presensi scan wajahnya di perbaikilah bikin or...
# 44   sinyal lancar tapi tetep muter terus apk gk guna
# 46                          sangat membantu pelajaran
# 47  scan absennya gak bisa di zoom jadi kepaksa ha...
# 48  halo kak waktu sedang mengerjakan quiz kamera ...
# 49  pada saat mengupload tugas tidak ada notifikas...
# 50  sistem quiz error soal ada udah isi sumua mala...
# 51  bikin auto save lah kak bjir lah gw bikin jawa...
# 52  benerin server nya oiiii jangan update fitur m...
# 54  sekarang edlink kalo isi quiz mau record atau ...
# 55  tolong adakan fitur zoom pada fitur scan code ...
# 56                                  ga berfungsi baik
# 57  halloaplikasi edlink sudah ada di perangkat la...
# 58                       kode tidak terkirim ke email
# 59  server selalu sibuk saat mengerjakan kuis saya...
#
#                                         text_StopWord
# 0      bintang sevima menyediakan mode gelap aplikasi
# 1                                    masuk mulu berak
# 4   izin melapor ketua aplikasi ngebug jaringan pa...
# 5   ko ganti hp g notif tugas kuis edlink muncul p...
# 7   membantu banget liat nilai nilai semester ga r...
# 8   aplikasi bagus upload tugas ujian aplikasi tul...
# 11  pengumpulan uas tugas dibaca dosen mengumpulka...
# 12  punten kie mah iya ngimpulaken tugas telat det...
# 13  ka tolong bantu mendaftarkan wajah pengaturan ...
# 14  durasi pengerjaan tugas jam sesuai sisa menit ...
# 15                      bagus terkadang bug absen aja
# 16              kesalahan server tolong dibenerin bug
# 17                             gak nge unduh file sih
# 18                                      bagusss mudah
# 19  mohon maaf ya buka apk edlink sinyal hp langsu...
# 20  buka materi perkuliahan download materi fileny...
# 21  makasih perbaiki zoom habis bug masuk zoom ses...
# 22  aplikasi bagus perkuliahan kukurangan pengapli...
# 23  make edlink bagus sih kali absensi suka mencar...
# 24                                    membantu semoga
# 25                      cobahehehesebenernya terpaksa
# 26                  membantu memudahkan proses beljar
# 27  kali buka kesalahan serverjadi tugas yg ga dik...
# 28  teruntuk developer aplikasi nay error mengisi ...
# 29                        fitur chat mahasiswa lambat
# 30                                    gakk ubah photo
# 31  bagus sih cuman ngumpul ujian temen loading be...
# 33  edlink jelek kalo dibuka pc gabisa ngelampirin...
# 35                 update ga absen scan wak bener aja
# 36  min tolong perbaiki quiz nya ngerjain nya gant...
# 37                                        quiz ngebug
# 38                                           membantu
# 39   hapus foto profil ganti ya muncul foto profilnya
# 40  kesalahan server tolong fix sampe gk tau samse...
# 41  presensi qr susah pakai pengnalan wajah wajah ...
# 42  presensi scan wajahnya perbaikilah bikin orang...
# 44                   sinyal lancar tetep muter apk gk
# 46                                 membantu pelajaran
# 47  scan absennya gak zoom kepaksa maju kedepan ke...
# 48  halo kak quiz kamera layar tibatiba hilang men...
# 49  mengupload tugas notifikasiindikasi persentase...
# 50  sistem quiz error udah isi sumua salah kemana ...
# 51  bikin auto save kak bjir gw bikin text editor ...
# 52  benerin server nya oiiii update fitur mulu nil...
# 54  edlink kalo isi quiz record ngga lemot yah ber...
# 55  tolong adakan fitur zoom fitur scan code kehad...
# 56                                       ga berfungsi
# 57   halloaplikasi edlink perangkat download hp pakai
# 58                                kode terkirim email
# 59  server sibuk kuis mengubah ter load sistem nya...

# %%
data_clean['text_StopWord'] = data_clean['text_StopWord'].fillna('')  # Isi NaN dengan string kosong
data_clean['text_StopWord'] = data_clean['text_StopWord'].astype(str)  # Konversi ke string

# %%
import nltk
nltk.download('punkt')
from nltk.tokenize import RegexpTokenizer

# Pastikan kolom tidak memiliki NaN
data_clean['text_StopWord'] = data_clean['text_StopWord'].fillna('')
data_clean['text_StopWord'] = data_clean['text_StopWord'].astype(str)

# Gunakan RegexpTokenizer untuk tokenisasi yang lebih stabil
tokenizer = RegexpTokenizer(r'\w+')
data_clean['text_tokens'] = data_clean['text_StopWord'].apply(lambda x: tokenizer.tokenize(x))
data_clean.head()

# %%
import nltk
nltk.download('punkt')
from nltk.tokenize import RegexpTokenizer

# Pastikan kolom tidak memiliki NaN
data_clean['text_StopWord'] = data_clean['text_StopWord'].fillna('')
data_clean['text_StopWord'] = data_clean['text_StopWord'].astype(str)

# Gunakan RegexpTokenizer untuk tokenisasi yang lebih stabil
tokenizer = RegexpTokenizer(r'\w+')
data_clean['text_tokens'] = data_clean['text_StopWord'].apply(lambda x: tokenizer.tokenize(x))
data_clean.head()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\abdullahilham\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[28], line 4
#       2 nltk.download('punkt')
#       3 from nltk.tokenize import sent_tokenize, word_tokenize
# ----> 4 data_clean['text_tokens'] = data_clean['text_StopWord'].apply(lambda x: word_tokenize(x))
#       5 data_clean.head()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[28], line 4, in <lambda>(x)
#       2 nltk.download('punkt')
#       3 from nltk.tokenize import sent_tokenize, word_tokenize
# ----> 4 data_clean['text_tokens'] = data_clean['text_StopWord'].apply(lambda x: word_tokenize(x))
#       5 data_clean.head()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\nltk\tokenize\__init__.py:142, in word_tokenize(text, language, preserve_line)
#     127 def word_tokenize(text, language="english", preserve_line=False):
#     128     """
#     129     Return a tokenized copy of *text*,
#     130     using NLTK's recommended word tokenizer
#    (...)
#     140     :type preserve_line: bool
#     141     """
# --> 142     sentences = [text] if preserve_line else sent_tokenize(text, language)
#     143     return [
#     144         token for sent in sentences for token in _treebank_word_tokenizer.tokenize(sent)
#     145     ]
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\nltk\tokenize\__init__.py:119, in sent_tokenize(text, language)
#     109 def sent_tokenize(text, language="english"):
#     110     """
#     111     Return a sentence-tokenized copy of *text*,
#     112     using NLTK's recommended sentence tokenizer
#    (...)
#     117     :param language: the model name in the Punkt corpus
#     118     """
# --> 119     tokenizer = _get_punkt_tokenizer(language)
#     120     return tokenizer.tokenize(text)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\nltk\tokenize\__init__.py:105, in _get_punkt_tokenizer(language)
#      96 @functools.lru_cache
#      97 def _get_punkt_tokenizer(language="english"):
#      98     """
#      99     A constructor for the PunktTokenizer that utilizes
#     100     a lru cache for performance.
#    (...)
#     103     :type language: str
#     104     """
# --> 105     return PunktTokenizer(language)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\nltk\tokenize\punkt.py:1744, in PunktTokenizer.__init__(self, lang)
#    1742 def __init__(self, lang="english"):
#    1743     PunktSentenceTokenizer.__init__(self)
# -> 1744     self.load_lang(lang)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\nltk\tokenize\punkt.py:1749, in PunktTokenizer.load_lang(self, lang)
#    1746 def load_lang(self, lang="english"):
#    1747     from nltk.data import find
# -> 1749     lang_dir = find(f"tokenizers/punkt_tab/{lang}/")
#    1750     self._params = load_punkt_params(lang_dir)
#    1751     self._lang = lang
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\nltk\data.py:579, in find(resource_name, paths)
#     577 sep = "*" * 70
#     578 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 579 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource punkt_tab not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt_tab')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt_tab/english/
#
#   Searched in:
#     - 'C:\\Users\\abdullahilham/nltk_data'
#     - 'C:\\Users\\abdullahilham\\AppData\\Local\\Programs\\Python\\Python311\\nltk_data'
#     - 'C:\\Users\\abdullahilham\\AppData\\Local\\Programs\\Python\\Python311\\share\\nltk_data'
#     - 'C:\\Users\\abdullahilham\\AppData\\Local\\Programs\\Python\\Python311\\lib\\nltk_data'
#     - 'C:\\Users\\abdullahilham\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************

# %%
# !pip install Sastrawi

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# %%
#-----------------STEMMING -----------------
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
#import swifter


# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}
hitung=0

for document in data_clean['text_tokens']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")
for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    hitung+=1
    print(hitung,":",term,":" ,term_dict[term])

print(term_dict)
print("------------------------")

# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]


#script ini bisa dipisah dari eksekusinya setelah pembacaaan term selesai
data_clean['text_steamindo'] = data_clean['text_tokens'].apply(lambda x:' '.join(get_stemmed_term(x)))
data_clean.head(20)

# %%
data_clean.to_csv('hasil_TextPreProcessing_shopee.csv', index= False) #kemudian simpan hasil text preprocessing ke file csv

# %%
#disini kita importkan library re, kemudian kita lakukan praproses
import re
def praproses(text):
    text = re.sub('<[^>]*>', '', text)
    emoticons = re.findall('(?::|;|=)()(?:-)?(?:\)|\(|D|P)',
                           text)
    text = (re.sub('[\W]+', ' ', text.lower()) +
            ' '.join(emoticons).replace('-', ''))
    return text

# %%
#membagi data menjadi data training dan testing dengan test_size = 0.20 dan random state nya 0
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data_clean['content'], data_clean['Label'], 
                                                    test_size = 0.20, 
                                                    random_state = 0)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_vectorizer = TfidfVectorizer()
tfidf_train = tfidf_vectorizer.fit_transform(X_train)
tfidf_test = tfidf_vectorizer.transform(X_test)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer()
vectorizer.fit(X_train)

# %%
X_train = vectorizer.transform(X_train)
X_test = vectorizer.transform(X_test)

# %%
from sklearn.naive_bayes import MultinomialNB

nb = MultinomialNB()
nb.fit(tfidf_train, y_train)

# %%
X_train.toarray()

# %%
y_pred = nb.predict(tfidf_test)

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, y_pred)

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

clf = MultinomialNB()
clf.fit(X_train, y_train)
predicted = clf.predict(X_test)

print("MultinomialNB Accuracy:", accuracy_score(y_test,predicted))
print("MultinomialNB Precision:", precision_score(y_test,predicted, average="binary", pos_label="Negatif"))
print("MultinomialNB Recall:", recall_score(y_test,predicted, average="binary", pos_label="Negatif"))
print("MultinomialNB f1_score:", f1_score(y_test,predicted, average="binary", pos_label="Negatif"))

print(f'confusion_matrix:\n {confusion_matrix(y_test, predicted)}')
print('====================================================\n')
print(classification_report(y_test, predicted, zero_division=0))

# Load dataset
data_clean = pd.read_csv('hasil_TextPreProcessing_shopee.csv')

#
